# %% [markdown]
# #«Разработка автоматической диалоговой системы на основе языковой модели для анализа экономических новостей»

# %% [markdown]
# ##Загрузка необходимых библиотек

# %%
# !pip install langchain_openai==0.3.0 -q
# !pip install langchain_community==0.3.14 -q
# !pip install chromadb==0.5.0 -q
# !pip install sentence_transformers==3.3.1 -q
# !pip install langchain_huggingface==0.1.2 -q
# !pip install langchain_chroma==0.2.0 -q
# !pip install langchain_core==0.3.29 -q
# !pip install pydantic==2.10.5 -q
# !pip install onnxruntime==1.20.1 -q
# !pip install feedparser -q
# !pip install requests -q
# !pip install telebot -q
# !pip install gradio -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-text-splitters 0.3.8 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 0.3.29 which is incompatible.
# langchain 0.3.25 requires langchain-core<1.0.0,>=0.3.58, but you have langchain-core 0.3.29 which is incompatible.

# %%
import requests
import os
from bs4 import BeautifulSoup
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from google.colab import userdata
from langchain.schema.output_parser import StrOutputParser
from langchain_huggingface import ChatHuggingFace
from transformers import pipeline
import telebot

# %% [markdown]
# ##Парсинг новостей

# %% [markdown]
# Данные, на основе которых модель будет отвечать на вопросы пользователя будут взяты с сайта 'https://www.rbc.ru/economics/'
#
# Для парсинга воспользуемся библиотеками BeautifulSoup и requests

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
main_url = 'https://www.rbc.ru/economics/'

response = requests.get(main_url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
#находим все ссылки на интересующие нас статьи(нас интересуют те, которые попадают в рубрику "экономика")
links = []
for tag in soup.find_all('a', href=True):
    href = tag['href']
    if href.startswith('https://www.rbc.ru/') and '/economics/' in href:
        links.append(href)

#оставляем только уникальные ссылки
links = list(set(links))
print(links)
# Out:
# ['https://www.rbc.ru/economics/20/05/2025/682c42a39a794735ffe95a55', 'https://www.rbc.ru/economics/22/05/2025/682e80d09a794773e6b1fa6e', 'https://www.rbc.ru/economics/21/05/2025/682de33c9a794756f79632ef', 'https://www.rbc.ru/economics/27/05/2025/68355e739a7947343fa68c4a', 'https://www.rbc.ru/economics/20/05/2025/682b930a9a7947dc8c10ff8e', 'https://www.rbc.ru/economics/20/05/2025/682c22bc9a7947733044a0cf', 'https://www.rbc.ru/economics/21/05/2025/682ce0589a7947c3ec5cd612', 'https://www.rbc.ru/economics/27/05/2025/6835a5c79a79477cbf2ba6b9', 'https://www.rbc.ru/economics/?utm_source=topline', 'https://www.rbc.ru/economics/', 'https://www.rbc.ru/economics/27/05/2025/683568ed9a79472dae277da8', 'https://www.rbc.ru/economics/23/05/2025/682fdcf69a794703803b86bd', 'https://www.rbc.ru/interview/economics/21/05/2025/6829a8669a79473f7917e4e3', 'https://www.rbc.ru/economics/20/05/2025/682b9cd39a79471d6050da25', 'https://www.rbc.ru/economics/27/05/2025/6835bf899a7947ce81b0f3ed', 'https://www.rbc.ru/economics/26/05/2025/68343a309a7947c59e2a8197']

# %%
def get_article_text(url): #пишем функцию, которая будет извлекать текст статьи
    try:
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, 'html.parser')

        content = soup.find('div', {'class': 'article__text'}) #пробуем найти текст статьи внутри этих тегов
        if not content:
            content = soup.find('div', {'class': 'l-container'})  #если первый вариант считывания не сработал

        paragraphs = content.find_all('p')
        text = '\n'.join(p.get_text(separator=" ", strip=True) for p in paragraphs)

        return (url, text)

    except Exception as e:
        pass

# %%
#получаем список ссылок и текстов всех новостей
texts_n_links = []
for link in links:
    article_text = get_article_text(link)
    texts_n_links.append(article_text)

texts_n_links
# Out:
# [('https://www.rbc.ru/economics/20/05/2025/682c42a39a794735ffe95a55',
#   'Центробанк использует возможности искусственного интеллекта (ИИ), но он не может принимать решения вместо экспертов, в частности, по ключевой ставке, заявила председатель Банка России Эльвира Набиуллина на «Альфа-Саммите».\n«Можно\xa0ли нас заменить искусственным интеллектом при принятии решения о ключевой, хотя\xa0бы чуть-чуть? Сначала об искусственном интеллекте: мы действительно стараемся использовать возможности искусственного интеллекта. Я лично считаю, что там есть большой потенциал, но пока не в макроэкономическом анализе и прогнозировании»,\xa0— отметила глава ЦБ.\nНабиуллина пояснила, что ИИ учится на больших рядах данных, взятых из прошлого. Сейчас «по историческим меркам\xa0у нас не очень большие ряды данных», указала председатель Банка России. Кроме того, в условиях «структурной трансформации, когда старые связи между данными не работают, вообще выводы моделей, не только искусственного интеллекта, они ограничены». По этим причинам роль человека-макроэкономиста важна, заключила Набиуллина.\nПо ее словам, регулятор использует ИИ при работе с жалобами, так как работать вручную с ними сложно, а новые технологии позволяют «эти жалобы классифицировать, на типовые отвечать и маршрутизировать их». Кроме того, ЦБ пытался использовать ИИ для рерайта своих материалов, чтобы сделать их «понятнее и прозрачнее».\n«Правда, мои коллеги все-таки перешли на ручной режим опять, потому что каких-то нюансов там не хватает, когда искусственный интеллект прописывает. Они говорят, что уважаемые аналитики не поймут [переписанный ИИ материал]»,\xa0— пояснила Набиуллина.\nНабиуллина назвала высокую ключевую ставку «проверенным лекарством» Экономика\nДнем ранее, 19 мая, глава Следственного комитета Александр Бастрыкин рассказал, как ИИ помогает раскрывать преступления. По его словам, алгоритмы помогли в расследованиях убийств дочери философа Александра Дугина Дарьи Дугиной, военкора Владлена Татарского,\xa0найти тех, кто покушался на писателя Захара Прилепина и ведущего Владимира Соловьева.\n\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/22/05/2025/682e80d09a794773e6b1fa6e',
#   'Менее пятой части россиян (17%) поддержали идею о введении фиксированного НДФЛ и взноса в фонд обязательного медицинского страхования (ОМС) для неработающих официально граждан, получающих теневые доходы, и «профессиональных бездельников», следует из результатов исследования SuperJob (есть у РБК).\nОпрос проводился 15–20 мая, в нем участвовали 1,6 тыс. экономически активных россиян старше 18 лет.\nПротив такой меры выступили 63% респондентов. «С каких средств неработающий ребенок и домохозяйка будут платить налоги? С денег отца/мужа? А разве его доходы уже не обложены налогами?!»\xa0— говорили участники опроса.\nНалог на «бездельника». За что могут заплатить неработающие в России Подписка на\xa0РБК\nАналитики отмечают, что именно попадание домохозяек в список «профессиональных бездельников» вызвало много споров: «Они и так работают бесплатно, пытаясь развивать институт семьи в России».\nКаждый пятый затруднился с оценкой идеи.\nПротивников инициативы больше среди респондентов младше 35 лет (67%), нежели среди участников опроса старше этого возраста. Среди мужчин идея нашла больше сторонников (20%), чем среди женщин (14%).\nТакже уровень одобрения введения подобной меры повышается по мере роста доходов:\nВласти решили установить, кто и почему в России не работает Экономика\nС идеей о введении фиксированного НДФЛ и взноса в фонд ОМС для «профессиональных бездельников» на иждивении и неработающих официально граждан, получающих теневые доходы, в мае выступил профессор Финансового университета при правительстве России Александр Сафонов, подчеркнув, что они пользуются социальными благами, не платя ничего в государственную казну.\nВ колонке для РБК он отметил, что из почти 15 млн неработающих россиян трудоспособного возраста теоретически вовлечь на рынок труда в условиях рекордного дефицита кадров можно лишь около 1,5 млн человек. При этом часть из них и так работает, но не официально, а часть\xa0— просто не хочет, подчеркивает Сафонов.\nВместе с тем он признал, что вовлечение в занятость рантье\xa0— нереализуемая задача. Поэтому основным путем работы с ними может быть «обеление», а для этого, считает экономист, можно ввести обязательных страховых взносов и фиксированный НДФЛ.\nТе\xa0же меры Сафонов предложил применить к тем, кого он характеризует как «профессиональных бездельников». Это дети богатых родителей, домохозяйки, лица, живущие за счет своих родственников или знакомых, граждане, получающие пособия на детей (за исключением тех, кто ухаживает за инвалидами, или многодетных родителей), «профессиональные безработные».\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/21/05/2025/682de33c9a794756f79632ef',
#   'При текущем уровне добычи разведанных запасов нефти в России хватит на 26 лет, сообщил глава Минприроды Александр Козлов во время правительственного часа в Госдуме.\nИз 31 млрд т запасов нефти, которыми располагает Россия, рентабельны только 13 млрд т, рассказал министр.\n«Из этих запасов значительная часть\xa0— это трудноизвлекаемые запасы, на которые были вовремя даны налоговые льготы, что позволило сделать их добычу рентабельной»,\xa0— уточнил он (цитата по «РИА Новости» ).\nТакже Россия располагает 95 млрд т нефтяных ресурсов, продолжил глава Минприроды. «Их отличие [заключается] в том, что ресурсы надо еще подготовить за счет геологоразведки\xa0— как государством, так и компаниями, и только потом перевести их в запасы»,\xa0— пояснил Козлов.\nРоссия сократила поставки сырой нефти в Китай Экономика\nЗапасы нефти\xa0— количество нефти, которое содержится в недрах в изученных бурением залежах.\nРесурсы нефти\xa0— количество нефти, которое содержится в невскрытых бурением нефтегазоносных или перспективных нефтегазоносных пластах.\nПо оценке правительства, добыча нефти с конденсатом в России по итогам 2024 года составила 516,1 млн т . Минэкономразвития прогнозирует, что в 2025 году добыча снизится на символические 0,02%\xa0— до 516 млн т, а в 2026 году, напротив, вырастет до 525,2 млн т. В 2027 году, по предварительным подсчетам, она должна увеличиться до 532,6 млн т, а в 2028 году\xa0— до 540 млн т.\nРоссия входит в число мировых лидеров по запасам полезных ископаемых. На начало 2022 года она занимала пятое место в мире по запасам углеводородов. Основные запасы нефти в стране сосредоточены в Западной Сибири.\nРазработка новых месторождений при этом идет ежегодно. Только в 2024 году было открыто 39 новых месторождений углеводородов, самые значительные\xa0— в Иркутской области, ЯНАО, Красноярском крае и Якутии.\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/27/05/2025/68355e739a7947343fa68c4a',
#   'Горнодобывающим компаниям из США и Европы «нужно поторопиться и инвестировать» в Гренландию, иначе ей придется искать помощь в разработке полезных ископаемых в других странах, в том числе в Китае, заявила в интервью Financial Times министр по делам бизнеса, торговли, минеральных ресурсов, юстиции и гендерного равенства Наая Натаниэльсен.\n«Мы хотим развивать наш бизнес-сектор и диверсифицировать его, а для этого нужны инвестиции извне,\xa0— сказала она.\xa0— Мы действительно хотим сотрудничать с европейскими и американскими партнерами. Но если они не придут, я думаю, нам нужно искать что-то другое».\nНатаниэльсен отметила, что срок действия меморандума о взаимопонимании по разработке полезных ископаемых с США, подписанного во время первого президентского срока Дональда Трампа (2017–2021), истекает, и Гренландия безуспешно пыталась выяснить намерения Вашингтона его продлить при администрации Джо Байдена.\nГренландия\xa0— бывшая колония Дании, остается под ее контролем и является самым большим островом в мире, расположенным северо-восточнее Северной Америки. Ее площадь составляет около 2,2 млн кв. км, там проживают около 57 тыс. человек. Остров богат природными ресурсами. Как уточнял The Economist, там расположены залежи 43 из 50 минералов, которые США относят к критически важным.\nС XIX века власти США неоднократно поднимали тему приобретения Гренландии. Там также находится американская авиабаза Туле. В частности, о желании получить контроль над островом говорил Трамп. После возвращения в Белый дом он не исключал возможность применения военной силы в этих целях.\n«Мы надеялись, что администрация Трампа будет более охотно вести диалог с Гренландией о развитии горнодобывающей отрасли. Мы получили немного больше, чем просили, потому что мы не хотим быть американцами»,\xa0— заявила министр, отметив, что угрозы президента США являются «неуважительными и неприятными».\nWSJ рассказала о найденной во льдах Гренландии секретной военной базе США Политика\nВ отличие от США, Китай не проявляет большого\xa0интереса к сделкам в сфере добычи полезных ископаемых, возможно, потому что не хочет «ничего провоцировать», предположила Натаниэльсен. По ее словам, на данный момент в Гренландии работают две китайские горнодобывающие компании. «Мы пытаемся понять, как выглядит новый мировой порядок. С этой точки зрения китайские инвестиции, конечно, проблематичны, но в какой-то степени проблематичны и американские,\xa0— сказала она.\xa0— Потому что какова цель [инвестиций США]»?\nНатаниэльсен считает, что для Гренландии «хорошо подходит» ЕС, так как имеет необходимые ей полезные ископаемые и придерживается экологических стандартов.\nВ конце марта премьер-министр Гренландии Йенс-Фредерик Нильсен в ответ на заявления Трампа о присоединении острова к США заявил , что население самостоятельно определяет свое будущее и не принадлежит никому. «Мы должны четко, ясно и спокойно показать американскому президенту, что Гренландия наша»,\xa0— написал он в Facebook (принадлежит компании Meta, признанной экстремистской и запрещенной в России). Премьер Дании Метте Фредериксен подчеркивала, что остров является автономной территорией и не продается.\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/20/05/2025/682b930a9a7947dc8c10ff8e',
#   'США, введя антироссийские санкции, наступили «на грабли», которые называются\xa0«подрыв позиций доллара как мировой резервной валюты», заявил в интервью РБК министр по развитию Дальнего Востока и Арктики Алексей Чекунков. По его словам, доля доллара в международных расчетах и резервах снижается, а «свято место пусто не бывает»\xa0— появляются новые расчетные механизмы.\n«Если страны отказываются от американского госдолга и если сами американцы не дают странам рассчитываться в долларах, то торговая практика смещается в сторону каких-то других валют. А зачем назад возвращаться?»\xa0— заявил Чекунков.\nГлава Минвостокразвития: «Не согласен, что ресурсы\xa0— это\xa0плохо» Экономика\n«Долларовая система расчетов многие десятилетия пользовалась монопольной позицией. Взять хотя\xa0бы дуополию Visa и Mastercard. Очень дорогие, ненужные, честно говоря, потребителю способы расплачиваться: каждый раз, когда человек касается пластиковой карточкой терминала, платить кому-то в Америке 2%\xa0— это абсурд. То есть как раз это и есть монопольная рента»,\xa0— сказал министр.\nFA назвала Трампа угрозой статусу доллара как мировой резервной валюты Политика\nVisa и Mastercard взимают по 1% за проведение транзакций за пределами США. В марте 2022 года эти платежные системы приостановили работу в России. Их карты, выпущенные российскими банками, перестали работать за границей, но продолжили функционировать внутри страны, так как операции по ним обрабатываются НСПК.\nПо словам Чекункова, американские санкции начали «отдавать рикошетом» по их инициаторам. Поэтому, по его мнению, санкции, связанные с международными расчетами, «будут первыми в очереди на смягчение».'),
#  ('https://www.rbc.ru/economics/20/05/2025/682c22bc9a7947733044a0cf',
#   'За январь—апрель 2025 года Китай импортировал 32,386 млн т сырой нефти, или 239,7 млн баррелей, что на 14,3% меньше по сравнению с аналогичным периодом прошлого года, следует из данных Главного таможенного управления КНР. Общая таможенная стоимость составила $17,085 млрд.\nОбщий объем импорта сырой нефти в Китай в апреле составил 48,06 млн т, из них на Россию приходится 8,07 млн т (59,7 млн баррелей) на $3,909 млрд, что на 12,9% меньше по сравнению с апрелем 2024 года.\nСогласно данным китайского таможенного управления, в прошлом месяце Россия стала лидером по объему поставок сырой нефти в Китай. На втором и третьем местах\xa0— Малайзия (7,95 млн т) и Саудовская Аравия (5,53 млн т).\nЗа январь—апрель 2024 года объем импорта российской нефти в Китай составил 37,778 млн т (280 млн баррелей) на сумму $22,475 млрд, из них поставки в апреле достигали 9,26 млн т (68,48 млн баррелей) на $5,793 млрд.\nРБК направил запрос в пресс-службу Минэнерго России.\nКремль заявил, что национальные интересы России важнее цен на нефть Бизнес По итогам 2024 года объем импорта Китая сырой нефти из России достиг рекордных 108,5 млн т. По данным Reuters , спрос был зафиксирован как со стороны частных нефтеперерабатывающих заводов, так и государственных нефтяных компаний Пекина. Вместе с тем общий объем китайского импорта сырой нефти снизился на 1,9% из-за замедления экономического роста и высокого спроса на топливо.\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/21/05/2025/682ce0589a7947c3ec5cd612',
#   '«Две недели назад я просил аппарат премьер-министра [Италии] обсудить эти важные моменты во взаимоотношениях между Италией и Россией, чтобы наше правительство знало о готовности торговой палаты участвовать в этом процессе,\xa0хотя\xa0бы для анализа, какого уровня санкции можно снять в приоритетном порядке и какой эффект каждая ограничительная мера реально может дать для развития экономики Италии»,\xa0— рассказал в интервью РБК Венченцо Трани, президент Итало-российской торговой палаты.\nТак он прокомментировал инициативу своего «коллеги»,\xa0главы Американской торговой палаты в России Роберта Эйджи: как стало известно в марте, руководитель делового бизнес-сообщества подготовил white paper для властей США\xa0— доклад, содержащий предложения по снятию санкций с России. В первую очередь речь шла об «авиационных» санкциях, запрещающих обслуживание западных пассажирских самолетов в России и поставку авиазапчастей.\nГлава Итало-Российской торговой палаты: «Мы не можем работать свободно» Экономика\n«Между Американской и Итало-российской торговыми палатами всегда были отношения, мы часто общаемся,\xa0— рассказал Трани.\xa0— На самом деле я очень поддерживаю шаги, которые сейчас продвигает Роберт. Особенно это касается снятия санкций по авиационному направлению. Потому что ограничения в авиации\xa0— это, с моей точки зрения, очень грубые санкции, нацеленные на убийство населения, которое использует гражданские авиалинии. В случае\xa0если что-то произойдет, ответственность больно ляжет на те страны, которые ввели эти санкции. Поэтому я очень поддерживаю инициативу по их снятию».\nПо словам Трани, раньше экспорт из Италии в Россию оценивался в €8–9 млрд в год: «Сегодня мы экспортируем около €4 млрд\xa0— мы потеряли половину. И это в то время, когда существует таможенная пошлина на экспорт товаров в США».\nСобеседник РБК вспоминает два главных пункта «из риторики» бывшего премьер-министра Италии\xa0(с февраля 2021\xa0по июль 2022 года) Марио Драги против России: «Первый\xa0— то, что связано с энергетикой:\xa0мы можем покупать газ у кого-то другого, необязательно покупать у России. А неделю назад в прессе была статья с его заявлением, что на самом деле Италия не имеет будущего при сегодняшней стоимости энергоресурсов. Соответственно, у меня вопрос: а\xa0раньше вы не могли подумать об этом? Ведь эти санкции были введены, когда вы были премьер-министром. Второй пункт касался возможностей для итальянских компаний перенаправить выпадающие от экспорта в Россию объемы в США, в том числе с финансированием со стороны правительства.\xa0У нас есть агентство по развитию экспорта ICE (Italian Trade Agency)\xa0— оно помогало и финансировало государственными деньгами перестройку сети дистрибуции для компаний, которые до этого поставляли товары в Россию, чтобы они теперь экспортировали в США. У этой политики, как мы видим, тоже «хороший» результат».\nЭкономика должна быть основана «на нормальных, дружеских отношениях между разными странами», уверен Трани. По его словам, «нужно сосредоточиться на том, чтобы эти отношения были хорошими»: «Политические связи основаны на бизнесе. Чем сильнее будет бизнес, тем лучше будут эти связи. Поэтому, когда какое-то правительство решает через санкции полностью закрыть бизнес-отношения с другими странами, это противоречит логике развития здоровой экономики».\nЧитайте РБК в Telegram.'),
#  ('https://www.rbc.ru/economics/27/05/2025/6835a5c79a79477cbf2ba6b9',
#   'Губернатор Калининградской области Алексей Беспрозванных запретил вывозить картофель из региона, об этом он заявил на заседании регионального правительства, его слова приводит «Клопс».\n«Мы пока по овощной группе точно себя не обеспечиваем. Приоритет в поддержке сельхозпроизводителей должен отдаваться проектам по обеспечению региона овощами. В частности, часть картофеля вывозится. Пока мы сами не обеспечиваемся, не нужно вывозить картофель из региона»,\xa0— сказал Беспрозванных, обращаясь к министру сельского хозяйства области Артему Иванову.\nРегион «до конца сам себя не обеспечивает», но аграрии вывозят картофель, обратил внимание губернатор.\nПутин процитировал слова Лукашенко о проданной России картошке Политика\n«Картофель завозится уже по другой цене, и понимаем, какая у нас цена на полке»,\xa0— отметил он, добавив, что таким образом область дважды «логистику оплачивает». Глава региона не исключил, что местный картофель обратно и привозят.\n«Пока не обеспечились, все необходимо оставлять в регионе»,\xa0— поручил Беспрозванных.\nРегиональный минсельхоз в мае заявил , что область полностью себя обеспечила: в 2024 году было собрано 149 тыс. т картофеля, что на 12% больше, чем в предыдущий год. При этом было вывезено только 5% урожая, заверили там.\nТак ведомство ответило на жалобы жителей на резкое подорожание картофеля\xa0— до 100 руб. за 1\xa0кг.\nРост цен там объяснили тем, что «в регионе продается картофель, который завозится торговыми организациями из других стран или регионов России». Продавцы сами устанавливают цену, «исходя из закупочной стоимости, логистики, сезонности, спроса и предложения на рынке», сказало министерство. Там сообщили, что посадочные площади под картофель в этом году увеличены еще на 400 га, до порядка 4 тыс. га. На сегодняшний день засажено уже 50% площадей, уточнили в ведомстве.\nМинсельхоз также связал подорожание картофеля с тем, что «традиционно весной запасы овощей сокращаются, а затраты на их хранение в овощехранилищах увеличиваются». «С появлением нового урожая стоимость картофеля снизится»,\xa0— заверили там.\nВ апреле министерство экономического развития, промышленности и торговли в ответ на вопрос жительницы в комментариях на странице губернатора во «ВКонтакте», «что у нас с ценами на картошку и капусту?», заявило , что «в торговых сетях на данный момент преимущественно представлены привозной картофель и капуста белокочанная».\nЖенщина прикрепила фотографию с ценой на белокочанную капусту\xa0— 169 руб. за 1 кг.\n«До начала сбора нового урожая на прилавках будет преобладать привозной картофель и капуста. Это обстоятельство также оказывает влияние на цены и ассортимент»,\xa0— сообщили там. В минэкпроме утверждают, что в «Пятерочке» килограмм капусты стоит 80 руб., а килограмм картофеля\xa0— 82 руб.\nПо данным Калининградстата, в марте наиболее подорожавшим продуктом стал картофель: цены на него выросли на 28,2% (63,9 руб. за 1 кг).\nЧитайте РБК в Telegram .'),
#  None,
#  None,
#  ('https://www.rbc.ru/economics/27/05/2025/683568ed9a79472dae277da8',
#   'Впервые за последние 34 года в списке стран\xa0— обладательниц крупнейших активов за рубежом сменился лидер: Япония уступила первое место Германии, которого та лишилась в 1991 году, сообщает Bloomberg . По итогам 2024 года совокупные чистые внешние активы Японии превысили ¥533 трлн, или $3,7 трлн, свидетельствуют данные Министерства финансов страны. За год размер таких активов увеличился на 13% (было ¥471,3 трлн), однако этого оказалось недостаточно, чтобы сохранить лидерство. Чистые внешние активы Германии за тот\xa0же год выросли более чем на 25%\xa0— до ¥569,7 трлн ($3,966 трлн), что и позволило Германии вернуть себе первое место. На третьем остался Китай\xa0— его чистые внешние активы также выросли более чем на 25%, с ¥412,7 трлн до ¥516,3 трлн.\nЧистые внешние / заграничные активы (Net Foreign / External Assets)\xa0— разница между общими активами страны и ее резидентов, находящимися за границей (включая прямые инвестиции), и общей суммой обязательств перед иностранцами (включая их вложения в национальные ценные бумаги). Если чистые иностранные активы страны положительны, она имеет за рубежом больше активов, чем сама должна иностранцам, это указывает на способность получать доходы из-за границы. Отрицательный показатель подразумевает, что страна накопила больше обязательств перед иностранцами, чем сама имеет активов за рубежом, что потенциально представляет угрозу экономической стабильности.\nВозврат Германии на первое место Bloomberg связывает с состоянием торгового баланса страны и ростом курса евро по отношению к иене. По итогам 2024 года положительное сальдо Германии составило €248,7 млрд, тогда как тот\xa0же показатель Японии только €180 млрд.\nВ Минфине Японии к утрате лидерства отнеслись спокойно. «Учитывая то, что чистые внешние активы Японии неуклонно растут, [новый] рейтинг сам по себе не следует воспринимать как признак того, что положение существенно изменилось»,\xa0— прокомментировал ситуацию министр финансов Кацунобу Като.\nПо данным ведомства, в 2024 году японские компании продолжили наращивать инвестиции в такие сектора экономик других стран, как финансы, страхование и розничная торговля, сохраняя «значительный аппетит» к вложениям в США и Великобританию. Bloomberg отмечает, что в будущем сохранению восходящей траектории может поспособствовать тарифная политика администрации президента США Дональда Трампа: из-за новых пошлин некоторые компании, чтобы снизить риски, могут активизировать усилия по переносу в США производственных мощностей или переводу туда других активов.\nГлавный экономист Mizuho Bank Дайсуке Каракама предупредил, что увеличение прямых инвестиций по сравнению с вложениями в ценные бумаги меняет ситуацию\xa0— в случае необходимости быстро вернуть в Японию вложенные в иностранные компании средства будет сложнее.'),
#  ('https://www.rbc.ru/economics/23/05/2025/682fdcf69a794703803b86bd',
#   'Монетный двор США планирует прекратить чеканить пенни (монеты достоинством ¢1), когда запасы заготовок закончатся, заказана последняя партия заготовок, сообщили в Минфине, передает AP.\nПо данным ведомства, стоимость производства пенни существенно выросла\xa0— более чем на 20% в 2024 году. Она составляет сейчас почти ¢4 за пенни.\nВ министерстве ожидают, что смогут сэкономить $56 млн в год за счет сокращения затрат.\nТрамп разместил шуточный ролик с намеком на свое вечное президентство Политика\nВ феврале президент Дональд Трамп поручил Минфину прекратить выпуск монет достоинством ¢1. «Слишком долго Соединенные Штаты чеканили пенни, которые буквально стоят дороже, чем ¢2. Это так расточительно!»\xa0— написал он в своей соцсети Truth Social.\nВ настоящее время в обращении находится около 114 млрд пенни ($1,14 млрд). Монетным двором в прошлом году было выпущено 3,2 млрд монет.\nПенни был одной из первых монет, изготовленных Монетным двором после его основания в 1792 году, отмечает AP. На аверсе (лицевой стороне монеты) изображен 16-й президент США Авраам Линкольн, на реверсе\xa0— щит с 13 вертикальными полосами, символизирующий государственное и национальное единство.\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/interview/economics/21/05/2025/6829a8669a79473f7917e4e3',
#   'Содержание: О возможности возобновления диалога между Россией и Италией О кризисе доверия О последствиях для итальянского бизнеса от ухода из России О возможном снятии санкций Об особенностях российской бизнес-культуры Сколько должен стоить «Делимобиль» Про российский, итальянский и немецкий автопром\nСодержание:\n— На фоне активизировавшихся контактов между Россией и США есть\xa0ли аналогичный диалог между Россией и Италией?\n— Диалог между Россией и США запустился только потому, что изменился лидер одной из сторон. Когда меняется партия или лидер, очень просто строить разговор снова. Можно просто сказать: «Это не я, это предыдущий человек». А когда вы управляли до и после, очень сложно перестроиться. Особенно это сложно, когда с той стороны\xa0— в данном случае в России\xa0— человек, который не передумал и никогда не ставил под сомнение то, что он сказал вчера, и последовательно придерживается своего мнения. Поэтому, когда с одной стороны есть позиция, которую мы в Италии называем coerenza (последовательность.\xa0— РБК ), другая сторона тоже не может показать «а я передумал». Поэтому выстраивать заново отношения между Россией и Италией очень сложно, даже если США построит этот мост. Потому что в США изменилось правительство, а в Италии\xa0— нет. Конечно, Европа имеет сильную зависимость от США, и рано или поздно эффект дойдет. Но нужно время\xa0— думаю, может быть, полтора-два года, чтобы вернуться в нормальный ракурс.\n— А как лично вы и ваши коллеги-бизнесмены восприняли возобновление российско-американского диалога в феврале, когда делегации впервые за долгое время встретились в Эр-Рияде?\n— Итальянские компании надеялись на сильные и быстрые изменения. Так продолжается и сейчас\xa0— мы все оптимистично смотрим на этот процесс. Но мы должны быть прагматичны и понимать, что США быстрее всех реагируют и делают так, чтобы выгода от любых переговоров была в первую очередь у них. А Европа всегда на втором месте. Поэтому мы понимаем, что когда будет какое-то изменение в отношениях между Россией и США, то американские компании станут первыми, кто вернется инвестировать, и только потом будут европейские. При этом сложно понять, как быстро европейские санкции могут быть сняты относительно американских.\nЯ с интересом слежу за Робертом Эйджи (глава Американской торговой палаты в России.\xa0— РБК ). Потому что со стороны его правительства есть большой интерес к «стройке отношений» и он имеет большую поддержку.\nВо времена, когда отношения нужно строить, торговая палата является принципиально важным каналом для этой деятельности. Итало-Российская торговая палата (ИРТП), которую я возглавляю, была создана в 1965 году\xa0— во времена СССР, когда было эмбарго, железный занавес и все остальное. Тогда Италия и Советский Союз работали через торговую палату над очень важной операцией...\nСовет ЕС одобрил новые санкции против России Политика\n— В 1966 году Fiat помог создать будущий АвтоВАЗ.\n— Эта сделка была началом истории торговой палаты. Поэтому ИРТП\xa0— очень важный канал, который ни в коем случае нельзя закрывать или ограничивать, ведь он развивает прагматичные отношения между странами и бизнесом. Палата решает задачи, которые важны для взаимоотношений между Россией и Италией во времена, когда другие каналы не работают. Но в текущей обстановке ИРТП ограничена в своих действиях. Мы не можем работать свободно, потому что нас просят соблюдать определенные указания итальянского правительства.\nМы возглавляли Совет Россия\xa0— Италия и были площадкой, через которую бизнес-делегации напрямую общались с правительствами. Это была роль, которую в свое время дал ИРТП Сильвио Берлускони. Поэтому канал для общения между Россией и Италией есть, мы очень многое можем делать. Но этот канал, к сожалению, на сегодняшний день работает на минимальном уровне. Потому что, если с итальянской стороны не хотят им пользоваться, что делать? Поэтому пока мы работаем, решая проблемы, которые могут быть у русских предпринимателей в Италии или у итальянских пр ...
#  ('https://www.rbc.ru/economics/20/05/2025/682b9cd39a79471d6050da25',
#   '«Самый известный современный инвестор Уоррен Баффетт отошел от дел буквально недавно, после 60 лет управления компанией, которая выросла на 10 млн процентов. Он инвестировал в бизнесы, которые были недооценены и приносили хорошую прибыль. Это и есть созидательный бизнес\xa0— брать и создавать добавленную стоимость»,\xa0— заявил в интервью РБК министр по развитию Дальнего Востока и Арктики Алексей Чекунков.\n94-летний инвестор-миллиардер Баффетт ранее в мае объявил , что уйдет с поста главного исполнительного директора Berkshire в конце года. После этого он останется председателем совета директоров компании. Bloomberg оценивает финансовое состояние бизнесмена в $161 млрд. В 2024 году Баффетт сообщал, что с 1965 года Berkshire Hathaway, которая в том числе активно инвестировала в «реальные» бизнесы (например, в железные дороги) ежегодно увеличивала свою рыночную стоимость в среднем на 19,8%.\nМинистр Чекунков предложил модель патриотического социализма для России Политика\nВ 2024 году в статье для РБК Чекунков предложил в качестве альтернативы массовому предпринимательству культуру «служения и созидания». «Вместо неприжившихся «бизнеса/предпринимателей», увязших в заботе правоохранителей, на первый план выйдут созидатели\xa0— более альтруистичные и патриотичные, но не менее конкурентные, чем охотники за прибылью. Со стороны государства в связке с ними будут работать служители\xa0— наследники традиций Горчакова, Муравьева-Амурского и Косыгина»,\xa0— писал он.\nВ интервью РБК министр уточнил, что говорил об идеальной модели. «Это союз государства и бизнеса: бизнес без государства не может конкурировать в современных условиях, тем более в такой стране, как Россия»,\xa0— пояснил он.\n«С точки зрения «созидателей», происходит поколенческий сдвиг: еще 10–15 лет назад были свежи в памяти истории быстрых денег. Первые кооперативы, перестройка, 1990-е\xa0— люди делали большое состояние буквально за год-два. Это был бизнес, но не созидание. Созидание\xa0— что-то новое создать. Согласитесь, что гораздо ценнее знать, как добыть баррель нефти с себестоимостью $20, чем знать, где купить и кому продать»,\xa0— сказал Чекунков.\nПри этом, по его словам, созидать можно и в освоении природных ресурсов. «Я, например, сильно не согласен с риторикой про ресурсный придаток и что ресурсы\xa0— это плохо. Просто знаю, что, например, добывать газ, или медный концентрат, или золото\xa0— это сложный, технологичный бизнес, как правило, с маржой 50–60%, с мощным инфраструктурным развитием, с высокими зарплатами. Чего здесь стесняться?»\xa0— подчеркнул он.'),
#  ('https://www.rbc.ru/economics/27/05/2025/6835bf899a7947ce81b0f3ed',
#   'Американский лидер Дональд Трамп выразил надежду на то, что ЕС «откроется» для торговли с США и одобрит его требование насчет Китая. Об этом он написал на своей странице в Truth Social.\n«Мне только что сообщили, что Евросоюз позвонил, чтобы быстро назначить даты встречи. Это позитивное событие, и я надеюсь, что они\xa0наконец, как и в случае с моим требованием к Китаю, откроют европейские страны для торговли с США. Они оба будут очень счастливы и успешны, если это сделают»,\xa0— написал он.\nКак писала газета The Wall Street Journal со ссылкой на источники, Трамп добивается от ЕС повышения пошлин на импорт товаров из Китая для заключения торгового соглашения с США.\nТрамп отложил введение 50-процентных пошлин для Евросоюза Политика\nВ начале апреля президент США объявил о введении пошлин на импорт товаров из разных стран. В частности, для ЕС и Китая их размер составил 20\xa0и 34% соответственно. Свое решение Трамп объяснил необходимостью «восстановить экономику и предотвратить мошенничество», так как США, по его словам, на протяжении десятилетий «подвергались разграблению, насилию и расхищению как друзьями, так и врагами». Он также заявил, что открыт для торговых переговоров, если собеседники предложат Вашингтону «что-то феноменальное».\nНа прошлой неделе американский лидер заявил , что переговоры с Брюсселем «ни к чему не приводят», и пригрозил ввести 50-процентные пошлины на европейский импорт с 1 июня.\nПосле этого, как писала The Wall Street Journal, комиссар ЕС по торговле Марош Шефчович созвонился с торговым представителем США Джеймисоном Гриром и министром торговли Говардом Лютником. После разговора Шефчович сообщил, что Евросоюз ведет торговые переговоры с Соединенными Штатами, но готов защищать свои интересы. Торговля «должна руководствоваться взаимным уважением, а не угрозами», убежден он.\nПозднее Трамп, отвечая на вопрос, что могут сделать страны ЕС, чтобы США изменили решение, сказал: «Не знаю».\nПосле телефонного разговора с главой Еврокомиссии Урсулой фон дер Ляйен американский президент все\xa0же отложил введение 50-процентных тарифов до 9 июля.\n\nЧитайте РБК в Telegram .'),
#  ('https://www.rbc.ru/economics/26/05/2025/68343a309a7947c59e2a8197',
#   'Минэкономразвития продолжает фиксировать риски переохлаждения российской экономики, заявил глава ведомства Максим Решетников, выступая в Госдуме на заседании комитета по бюджету и налогам.\nРешетников отметил, что в последние недели годовая инфляция в России варьируется в диапазоне 3–4%, если пересчитать по недельным данным. «Мы рассчитываем, что это своевременно будет учтено Центральным банком при принятии решений. Потому что мы также видим в текущем режиме риски переохлаждения экономики»,\xa0— сказал он.\nПо словам министра, текущий прогноз Минэкономразвития по инфляции в 2025 году на уровне 7,6% реалистичный, но больше учитывает накопленный потенциал конца 2024-го и начала 2025 года.\nВ апреле Минэкономразвития повысило прогноз по инфляции на 2025 год до 7,6% по сравнению с 4,5%, которые фигурировали в сентябрьской оценке. К концу 2026 года показатель достигнет целевого уровня в 4%. Эта оценка совпадает с прогнозом Банка России.\nЭкономика России, по оценкам Минэкономразвития, в 2025 году вырастет на 2,5%. При этом в среднесрочном прогнозе Банка России указано, что в 2025 году ВВП увеличится в диапазоне 1–2%.\nО проявлении «первых признаков охлаждения в экономике» Решетников заявил в феврале. Тогда он указал на замедление темпов роста в ряде отраслей, включая пищевую промышленность, химпром и машиностроение. О признаках охлаждения в ряде отраслей еще в декабре говорила глава Центробанка Эльвира Набиуллина. Тогда она перечислила строительную, угледобывающую и металлургическую отрасли.\nМинэк спрогнозировал «фрагментированный» рост экономики России Экономика\nПрезидент России Владимир Путин говорил , что охлаждение российской экономики неизбежно. При этом он призвал действовать «очень аккуратно» и не допустить «излишнего охлаждения, как в криокамере».\nЛетом прошлого года Набиуллина объявила о первом за десять лет циклическом перегреве экономики (когда для охлаждения спроса требуется длительный период сохранения высоких ставок). Тогда, в июле, регулятор впервые за семь месяцев повысил ключевую ставку с 16 до 18%.\nНа последнем заседании, которое состоялось 25 апреля, совет директоров Банка России принял решение сохранить ключевую ставку на рекордном уровне\xa0— 21% годовых. Это самое длинное в истории поддержание ставки на высоком уровне, на этом значении она сохраняется с 28 октября 2024 года.\n\nЧитайте РБК в Telegram .')]

# %% [markdown]
# ##Получение эмбеддингов новостей

# %% [markdown]
# Так как далее полученные тексты новостей мы будем передавать в LLM, то никакую специальную предобработку текстов производить не будем и ограничимся лишь получением эмбеддингов новостей

# %%
#получаем список только текстов новостей и преобразовываем их в Document
news_list = [elem[1] for elem in texts_n_links if elem]
documents = [Document(page_content=news) for news in news_list]

# %%
#загружаем сплиттер
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100)

# %%
split_docs = splitter.split_documents(documents)
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2" #выбираем модель - энкодер новостей
hf = HuggingFaceEmbeddings(
    model_name=model_name,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#в качестве базы данных для хранения эмбеддингов новостей выбрали Chroma
db = Chroma.from_documents(
    split_docs,
    hf,
    persist_directory="tmp"
)

# %%
#модель будет давать пользователю ответ на основе топ-2 результатов, которые вернет retriever
retriever = db.as_retriever(search_kwargs={"k": 2})

# %% [markdown]
# ## Определение моделей для ответа

# %% [markdown]
# Следующий список моделей будет использоваться для ответа на вопрос пользователя.
#
# Если у первой модели будет превышен лимит запросов к ней или будет выявлена какая-либо ошибка при генерации ответа, то будет использована следующая модель из списка.

# %%
models = [
    'mistralai/mistral-7b-instruct:free',
    "meta-llama/llama-4-maverick:free",
    "deepseek/deepseek-chat-v3-0324:free",
    "mistralai/mistral-small-3.1-24b-instruct:free",
]

# %% [markdown]
# Следующая функция будет определять, связан ли вопрос заданный пользователем с новостями или он общается на абстрактные темы. Это позволит повысить точность ответов модели, а также без необходимости не извлекать документы из базы данных.
#
# В зависимости от результата этой проверки будет использоваться либо модель, отвечающая на вопрос на основе новостей, либо модель, которая просто умеет вежливо поддерживать диалог.

# %%
def check_is_about_news(question):
    system_prompt_classifier = SystemMessagePromptTemplate.from_template('''Ты — классификатор. Твоя задача — определить, хочет ли пользователь получить информацию о текущих новостях, событиях или свежих фактах из мира.

    Если сообщение явно или косвенно спрашивает о новостях, ответь только "да".
    Если это приветствие, благодарность, комплимент или обычный разговор — ответь только "нет".

    Примеры:
    "что сегодня пишут про японию?" -> да
    "привет, спасибо, ты хороший бот" -> нет
    "какая погода в Москве?" -> нет
    "расскажи анекдот" -> нет
    "есть что-то про трампа?" -> нет. Ничего кроме "да" и "нет" писать нельзя!''')
    human_prompt_classifier = HumanMessagePromptTemplate.from_template('Пользователь задал вопрос: {question}. Верни "да", если пользователь спрашивает про новости и "нет" в инои случае.')
    chat_prompt_classifier = ChatPromptTemplate.from_messages([system_prompt_classifier, human_prompt_classifier])

    for model_name in models:
        try:
            model = ChatOpenAI(
                base_url="https://openrouter.ai/api/v1",
                api_key=userdata.get('firstkey'),
                model_name=model_name,
            )
            chain = chat_prompt_classifier | model | StrOutputParser()
            return chain.invoke({"question": question})

        except Exception as e:
            continue
    return "Не удалось получить ответ: все модели недоступны."

# %% [markdown]
# Следующая функция будет использована, если check_is_about_news вернет положительный ответ(то есть вопрос, заданный пользователем, связан с экономическими новостями)

# %%
def run_with_docs(question, docs):
    system_prompt = SystemMessagePromptTemplate.from_template('Ты — помощник, отвечающий на вопросы на основе предоставленных тебе новостей.')
    human_prompt = HumanMessagePromptTemplate.from_template('Ответь на вопрос: {question}. Вот несколько новостей, которые могут помочь ответить на этот вопрос: {docs}. Дай ответ, основанный только на предоставленных новостя. Если ты не уверен в ответе, то вовпроси уточнить вопрос или напиши "я не уверен, что могу ответить на этот вопрос"')
    chat_prompt = ChatPromptTemplate.from_messages([system_prompt, human_prompt])
    for model_name in models:
        try:
            model = ChatOpenAI(
                base_url="https://openrouter.ai/api/v1",
                api_key=userdata.get('firstkey'),
                model_name=model_name,
            )
            chain = chat_prompt | model | StrOutputParser()
            return chain.invoke({"question": question, "docs": docs})
        except Exception as e:
            continue
    return "Не удалось получить ответ: все модели недоступны."

# %% [markdown]
# Следующая функция будет использована, если check_is_about_news вернет отрицательный ответ(то есть вопрос, заданный пользователем, никак не связан с экономическими новостями)

# %%
def run_without_docs(question):
    system_prompt = SystemMessagePromptTemplate.from_template('Ты — ассистент пользователя, который с ним мило болтает и вежливо отвечает на его сообщения.')
    human_prompt = HumanMessagePromptTemplate.from_template('Пользователь задал вопрос: {question}. Вежливо ответь на его сообщение.')
    chat_prompt = ChatPromptTemplate.from_messages([system_prompt, human_prompt])
    for model_name in models:
        try:
            model = ChatOpenAI(
                base_url="https://openrouter.ai/api/v1",
                api_key=userdata.get('firstkey'),
                model_name=model_name,
            )
            chain = chat_prompt | model | StrOutputParser()
            return chain.invoke({"question": question})
        except Exception as e:
            continue
    return "Не удалось получить ответ: все модели недоступны."

# %% [markdown]
# Функция answer_question возвращает финальный ответ на вопрос пользователя

# %%
def answer_question(question):
    check = check_is_about_news(question)
    if 'да' in check.lower():
      docs = [elem.page_content for elem in retriever.invoke(question)]
      response = run_with_docs(question, docs)

    elif 'нет' in check.lower():
      response = run_without_docs(question)

    else:
      response = "Не удалось получить ответ: все модели недоступны."
    return response

# %% [markdown]
# ##Реализация телеграм-бота
#
# @EconomistAssistant_bot

# %%
bot = telebot.TeleBot(userdata.get('tg_token'));

@bot.message_handler(content_types=['text'])
def get_text_messages(message):
  if message.text.lower() == "Привет":
    bot.send_message(message.from_user.id, "Привет, чем я могу тебе помочь?")

  elif message.text == "/help":
      bot.send_message(message.from_user.id, 'Напиши "Привет"')

  else:
      bot.send_message(message.from_user.id, answer_question(message.text))

bot.polling(none_stop=True, interval=0)
# Out:
# <ipython-input-13-9cb2363d996b>:18: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   model = ChatOpenAI(

# %% [markdown]
# ##Реализация диалогового интерфейса с помощью gradio
#
# (запасной вариант)

# %%
import gradio as gr

gr.Interface(
    fn= answer_question,
    inputs=gr.Textbox(label="Введите вопрос"),
    outputs=gr.Textbox(label="Ответ ассистента"),
    title="Ваш ассистент по экономическим новостям",
).launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://007b12d2d1e2ccf151.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://007b12d2d1e2ccf151.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
